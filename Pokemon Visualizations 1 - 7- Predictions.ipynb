# %% [markdown]
# # Pokemon Visualizations 1-7 gen
#
# ## About this project
# This project aims to explore some information using few datasets with Pokemon data, then create a model using Pokemon battle dataset to predict which Pokemon would win a 1x1 battle.

# %% [markdown]
# ### Import data

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns

# %%
sns.set()
sns.set(rc={'figure.figsize':(14,10)})

# %% [markdown]
# ## Merge Pokemon datasets

# %%
df = pd.read_csv('Pokemon.csv')
df2 = pd.read_csv('pokemon2.csv')
df3 = df.merge(df2, on=['#'], how='right')
df = df3

# %%
df.head()
# Out:
#    #                 Name_x Type 1_x Type 2_x  Total  HP_x  Attack_x  \
# 0  1              Bulbasaur    Grass   Poison  318.0  45.0      49.0
# 1  2                Ivysaur    Grass   Poison  405.0  60.0      62.0
# 2  3               Venusaur    Grass   Poison  525.0  80.0      82.0
# 3  3  VenusaurMega Venusaur    Grass   Poison  625.0  80.0     100.0
# 4  4             Charmander     Fire      NaN  309.0  39.0      52.0
#
#    Defense_x  Sp. Atk_x  Sp. Def_x    ...     Weight  Base Experience  \
# 0       49.0       65.0       65.0    ...        6.9               64
# 1       63.0       80.0       80.0    ...       13.0              142
# 2       83.0      100.0      100.0    ...      100.0              236
# 3      123.0      122.0      120.0    ...      100.0              236
# 4       43.0       60.0       50.0    ...        8.5               62
#
#   Type 1_y Type 2_y  HP_y  Attack_y  Defense_y  Speed_y Sp. Atk_y Sp. Def_y
# 0    grass   poison    45        49         49       45        65        65
# 1    grass   poison    60        62         63       60        80        80
# 2    grass   poison    80        82         83       80       100       100
# 3    grass   poison    80        82         83       80       100       100
# 4     fire      NaN    39        52         43       65        60        50
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#        # Name_x Type 1_x Type 2_x  Total  HP_x  Attack_x  Defense_x  \
# 881  803    NaN      NaN      NaN    NaN   NaN       NaN        NaN
# 882  804    NaN      NaN      NaN    NaN   NaN       NaN        NaN
# 883  805    NaN      NaN      NaN    NaN   NaN       NaN        NaN
# 884  806    NaN      NaN      NaN    NaN   NaN       NaN        NaN
# 885  807    NaN      NaN      NaN    NaN   NaN       NaN        NaN
#
#      Sp. Atk_x  Sp. Def_x    ...     Weight  Base Experience  Type 1_y  \
# 881        NaN        NaN    ...        1.8              189    poison
# 882        NaN        NaN    ...      150.0              243    poison
# 883        NaN        NaN    ...      820.0              257      rock
# 884        NaN        NaN    ...       13.0              257      fire
# 885        NaN        NaN    ...       44.5              270  electric
#
#     Type 2_y  HP_y  Attack_y  Defense_y  Speed_y Sp. Atk_y Sp. Def_y
# 881      NaN    67        73         67       73        73        67
# 882   dragon    73        73         73      121       127        73
# 883    steel    61       131        211       13        53       101
# 884    ghost    53       127         53      107       151        79
# 885      NaN    88       112         75      143       102        80
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 886 entries, 0 to 885
# Data columns (total 26 columns):
# #                  886 non-null int64
# Name_x             800 non-null object
# Type 1_x           800 non-null object
# Type 2_x           414 non-null object
# Total              800 non-null float64
# HP_x               800 non-null float64
# Attack_x           800 non-null float64
# Defense_x          800 non-null float64
# Sp. Atk_x          800 non-null float64
# Sp. Def_x          800 non-null float64
# Speed_x            800 non-null float64
# Generation_x       800 non-null float64
# Legendary          800 non-null object
# Name_y             886 non-null object
# Generation_y       886 non-null int64
# Height             886 non-null float64
# Weight             886 non-null float64
# Base Experience    886 non-null int64
# Type 1_y           886 non-null object
# Type 2_y           461 non-null object
# HP_y               886 non-null int64
# Attack_y           886 non-null int64
# Defense_y          886 non-null int64
# Speed_y            886 non-null int64
# Sp. Atk_y          886 non-null int64
# Sp. Def_y          886 non-null int64
# dtypes: float64(10), int64(9), object(7)
# memory usage: 186.9+ KB

# %%
df.describe()
# Out:
#                 #      Total        HP_x    Attack_x   Defense_x   Sp. Atk_x  \
# count  886.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   401.803612  435.10250   69.258750   79.001250   73.842500   72.820000
# std    231.098223  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    206.250000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    397.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    602.750000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    807.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#         Sp. Def_x     Speed_x  Generation_x  Generation_y      Height  \
# count  800.000000  800.000000     800.00000    886.000000  886.000000
# mean    71.902500   68.277500       3.32375      3.680587    1.208804
# std     27.828916   29.060474       1.66129      1.917686    1.127585
# min     20.000000    5.000000       1.00000      1.000000    0.100000
# 25%     50.000000   45.000000       2.00000      2.000000    0.600000
# 50%     70.000000   65.000000       3.00000      4.000000    1.000000
# 75%     90.000000   90.000000       5.00000      5.000000    1.500000
# max    230.000000  180.000000       6.00000      7.000000   14.500000
#
#            Weight  Base Experience        HP_y    Attack_y   Defense_y  \
# count  886.000000       886.000000  886.000000  886.000000  886.000000
# mean    65.532731       150.958239   69.475169   77.804740   72.900677
# std    117.270966        76.450534   25.722925   30.021559   29.829255
# min      0.100000        36.000000    1.000000    5.000000    5.000000
# 25%      9.325000        67.000000   50.000000   55.000000   50.000000
# 50%     29.000000       159.000000   65.000000   75.000000   70.000000
# 75%     68.150000       184.750000   80.000000  100.000000   90.000000
# max    999.900000       608.000000  255.000000  181.000000  230.000000
#
#           Speed_y   Sp. Atk_y   Sp. Def_y
# count  886.000000  886.000000  886.000000
# mean    67.584650   71.585779   71.348758
# std     28.207887   30.503144   27.228708
# min      5.000000   10.000000   20.000000
# 25%     45.000000   50.000000   50.000000
# 50%     65.000000   65.000000   70.000000
# 75%     90.000000   95.000000   88.750000
# max    160.000000  173.000000  230.000000

# %% [markdown]
# ### Fix legendary

# %%
gen7_legendary_numbers = [772, 773, 785, 786, 787, 788, 789, 790, 791, 792, 800]
df.loc[df['Generation_y'] == 7, 'Legendary'] = False

df.loc[df['#'].isin(gen7_legendary_numbers), 'Legendary'] = True

# %% [markdown]
# ### Fix all status

# %%
x_columns = ['Name','Type 1','Type 2','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Generation']

for column in x_columns:
    df.loc[df[column+'_x'].isna(), column+'_x'] = df[column+'_y']

# %% [markdown]
# ### Remove '_y' columns and rename '_x' columns

# %%
df = df.drop(columns=['Name_y', 'Type 1_y','Type 2_y','Total','HP_y','Attack_y','Defense_y','Sp. Atk_y','Sp. Def_y','Speed_y','Generation_y'], axis=1)
df.rename(columns=lambda x: x.replace('_x', ''), inplace=True)

df['Type 1'] = map(lambda x: str(x).capitalize(), df['Type 1'])
df['Type 2'] = map(lambda x: x if x != x else str(x).capitalize(), df['Type 2'])
df['Name'] = map(lambda x: str(x).capitalize(), df['Name'])

df.head()
# Out:
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0
# 1  2                Ivysaur  Grass  Poison  60.0    62.0     63.0     80.0
# 2  3               Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 3  3  Venusaurmega venusaur  Grass  Poison  80.0   100.0    123.0    122.0
# 4  4             Charmander   Fire     NaN  39.0    52.0     43.0     60.0
#
#    Sp. Def  Speed  Generation  Legendary  Height  Weight  Base Experience
# 0     65.0   45.0         1.0      False     0.7     6.9               64
# 1     80.0   60.0         1.0      False     1.0    13.0              142
# 2    100.0   80.0         1.0      False     2.0   100.0              236
# 3    120.0   80.0         1.0      False     2.0   100.0              236
# 4     50.0   65.0         1.0      False     0.6     8.5               62

# %%
df.tail()
# Out:
#        #         Name    Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 881  803      Poipole    Poison     NaN  67.0    73.0     67.0     73.0
# 882  804    Naganadel    Poison  Dragon  73.0    73.0     73.0    127.0
# 883  805    Stakataka      Rock   Steel  61.0   131.0    211.0     53.0
# 884  806  Blacephalon      Fire   Ghost  53.0   127.0     53.0    151.0
# 885  807      Zeraora  Electric     NaN  88.0   112.0     75.0    102.0
#
#      Sp. Def  Speed  Generation  Legendary  Height  Weight  Base Experience
# 881     67.0   73.0         7.0      False     0.6     1.8              189
# 882     73.0  121.0         7.0      False     3.6   150.0              243
# 883    101.0   13.0         7.0      False     5.5   820.0              257
# 884     79.0  107.0         7.0      False     1.8    13.0              257
# 885     80.0  143.0         7.0      False     1.5    44.5              270

# %% [markdown]
# ### Adding Mega evolution column

# %%
df['Mega'] = False

# %%
df.loc[df['Name'].str.contains("mega "), 'Mega'] = True

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0
# 1  2                Ivysaur  Grass  Poison  60.0    62.0     63.0     80.0
# 2  3               Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 3  3  Venusaurmega venusaur  Grass  Poison  80.0   100.0    123.0    122.0
# 4  4             Charmander   Fire     NaN  39.0    52.0     43.0     60.0
#
#    Sp. Def  Speed  Generation  Legendary  Height  Weight  Base Experience  \
# 0     65.0   45.0         1.0      False     0.7     6.9               64
# 1     80.0   60.0         1.0      False     1.0    13.0              142
# 2    100.0   80.0         1.0      False     2.0   100.0              236
# 3    120.0   80.0         1.0      False     2.0   100.0              236
# 4     50.0   65.0         1.0      False     0.6     8.5               62
#
#     Mega
# 0  False
# 1  False
# 2  False
# 3   True
# 4  False

# %%
df.loc[df['Name'].str.contains("Mega")]
# Out:
#        #      Name Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 168  154  Meganium  Grass    NaN  80.0    82.0    100.0     83.0    100.0
#
#      Speed  Generation  Legendary  Height  Weight  Base Experience   Mega
# 168   80.0         2.0      False     1.8   100.5              236  False

# %%
types1 = df['Type 1'].unique()
types1_colors = ['#7AC74C', '#EE8130', '#6390F0', '#A6B91A', 
                 '#A8A77A', '#A33EA1', '#F7D02C', '#E2BF65', '#D685AD', '#C22E28', '#F95587', '#B6A136',
                 '#735797', '#96D9D6', '#6F35FC', '#705746', '#B7B7CE', '#A98FF3'
                ]

type1_colors = {}

for i, type1 in enumerate(types1):
    type1_colors[type1] = types1_colors[i]

# %% [markdown]
# ### Remove mega/duplicates/multiple form pokemon

# %%
df[df["Name"].str.contains(' forme')]
# Out:
#        #                      Name    Type 1    Type 2     HP  Attack  \
# 428  386        Deoxysnormal forme   Psychic       NaN   50.0   150.0
# 429  386        Deoxysattack forme   Psychic       NaN   50.0   180.0
# 430  386       Deoxysdefense forme   Psychic       NaN   50.0    70.0
# 431  386         Deoxysspeed forme   Psychic       NaN   50.0    95.0
# 544  487     Giratinaaltered forme     Ghost    Dragon  150.0   100.0
# 545  487      Giratinaorigin forme     Ghost    Dragon  150.0   120.0
# 550  492         Shayminland forme     Grass       NaN  100.0   100.0
# 551  492          Shayminsky forme     Grass    Flying  100.0   103.0
# 702  641   Tornadusincarnate forme    Flying       NaN   79.0   115.0
# 703  641     Tornadustherian forme    Flying       NaN   79.0   100.0
# 704  642  Thundurusincarnate forme  Electric    Flying   79.0   115.0
# 705  642    Thundurustherian forme  Electric    Flying   79.0   105.0
# 708  645   Landorusincarnate forme    Ground    Flying   89.0   125.0
# 709  645     Landorustherian forme    Ground    Flying   89.0   145.0
# 713  647      Keldeoordinary forme     Water  Fighting   91.0    72.0
# 714  647      Keldeoresolute forme     Water  Fighting   91.0    72.0
# 715  648        Meloettaaria forme    Normal   Psychic  100.0    77.0
# 716  648   Meloettapirouette forme    Normal  Fighting  100.0   128.0
# 750  681      Aegislashblade forme     Steel     Ghost   60.0   150.0
# 751  681     Aegislashshield forme     Steel     Ghost   60.0    50.0
# 794  718          Zygarde50% forme    Dragon    Ground  108.0   100.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Height  Weight  \
# 428     50.0    150.0     50.0  150.0         3.0       True     1.7    60.8
# 429     20.0    180.0     20.0  150.0         3.0       True     1.7    60.8
# 430    160.0     70.0    160.0   90.0         3.0       True     1.7    60.8
# 431     90.0     95.0     90.0  180.0         3.0       True     1.7    60.8
# 544    120.0    100.0    120.0   90.0         4.0       True     4.5   750.0
# 545    100.0    120.0    100.0   90.0         4.0       True     4.5   750.0
# 550    100.0    100.0    100.0  100.0         4.0       True     0.2     2.1
# 551     75.0    120.0     75.0  127.0         4.0       True     0.2     2.1
# 702     70.0    125.0     80.0  111.0         5.0       True     1.5    63.0
# 703     80.0    110.0     90.0  121.0         5.0       True     1.5    63.0
# 704     70.0    125.0     80.0  111.0         5.0       True     1.5    61.0
# 705     70.0    145.0     80.0  101.0         5.0       True     1.5    61.0
# 708     90.0    115.0     80.0  101.0         5.0       True     1.5    68.0
# 709     90.0    105.0     80.0   91.0         5.0       True     1.5    68.0
# 713     90.0    129.0     90.0  108.0         5.0      False     1.4    48.5
# 714     90.0    129.0     90.0  108.0         5.0      False     1.4    48.5
# 715     77.0    128.0    128.0   90.0         5.0      False     0.6     6.5
# 716     90.0     77.0     77.0  128.0         5.0      False     0.6     6.5
# 750     50.0    150.0     50.0   60.0         6.0      False     1.7    53.0
# 751    150.0     50.0    150.0   60.0         6.0      False     1.7    53.0
# 794    121.0     81.0     95.0   95.0         6.0       True     5.0   305.0
#
#      Base Experience   Mega
# 428              270  False
# 429              270  False
# 430              270  False
# 431              270  False
# 544              306  False
# 545              306  False
# 550              270  False
# 551              270  False
# 702              261  False
# 703              261  False
# 704              261  False
# 705              261  False
# 708              270  False
# 709              270  False
# 713              261  False
# 714              261  False
# 715              270  False
# 716              270  False
# 750              234  False
# 751              234  False
# 794              270  False

# %%
df_unique = df.drop_duplicates(subset="#")
df_unique
# Out:
#        #         Name    Type 1    Type 2     HP  Attack  Defense  Sp. Atk  \
# 0      1    Bulbasaur     Grass    Poison   45.0    49.0     49.0     65.0
# 1      2      Ivysaur     Grass    Poison   60.0    62.0     63.0     80.0
# 2      3     Venusaur     Grass    Poison   80.0    82.0     83.0    100.0
# 4      4   Charmander      Fire       NaN   39.0    52.0     43.0     60.0
# 5      5   Charmeleon      Fire       NaN   58.0    64.0     58.0     80.0
# 6      6    Charizard      Fire    Flying   78.0    84.0     78.0    109.0
# 9      7     Squirtle     Water       NaN   44.0    48.0     65.0     50.0
# 10     8    Wartortle     Water       NaN   59.0    63.0     80.0     65.0
# 11     9    Blastoise     Water       NaN   79.0    83.0    100.0     85.0
# 13    10     Caterpie       Bug       NaN   45.0    30.0     35.0     20.0
# 14    11      Metapod       Bug       NaN   50.0    20.0     55.0     25.0
# 15    12   Butterfree       Bug    Flying   60.0    45.0     50.0     90.0
# 16    13       Weedle       Bug    Poison   40.0    35.0     30.0     20.0
# 17    14       Kakuna       Bug    Poison   45.0    25.0     50.0     25.0
# 18    15     Beedrill       Bug    Poison   65.0    90.0     40.0     45.0
# 20    16       Pidgey    Normal    Flying   40.0    45.0     40.0     35.0
# 21    17    Pidgeotto    Normal    Flying   63.0    60.0     55.0     50.0
# 22    18      Pidgeot    Normal    Flying   83.0    80.0     75.0     70.0
# 24    19      Rattata    Normal       NaN   30.0    56.0     35.0     25.0
# 25    20     Raticate    Normal       NaN   55.0    81.0     60.0     50.0
# 26    21      Spearow    Normal    Flying   40.0    60.0     30.0     31.0
# 27    22       Fearow    Normal    Flying   65.0    90.0     65.0     61.0
# 28    23        Ekans    Poison       NaN   35.0    60.0     44.0     40.0
# 29    24        Arbok    Poison       NaN   60.0    85.0     69.0     65.0
# 30    25      Pikachu  Electric       NaN   35.0    55.0     40.0     50.0
# 31    26       Raichu  Electric       NaN   60.0    90.0     55.0     90.0
# 32    27    Sandshrew    Ground       NaN   50.0    75.0     85.0     20.0
# 33    28    Sandslash    Ground       NaN   75.0   100.0    110.0     45.0
# 34    29     Nidoran♀    Poison       NaN   55.0    47.0     52.0     40.0
# 35    30     Nidorina    Poison       NaN   70.0    62.0     67.0     55.0
# ..   ...          ...       ...       ...    ...     ...      ...      ...
# 856  778      Mimikyu     Ghost     Fairy   55.0    90.0     80.0     50.0
# 857  779      Bruxish     Water   Psychic   68.0   105.0     70.0     70.0
# 858  780       Drampa    Normal    Dragon   78.0    60.0     85.0    135.0
# 859  781     Dhelmise     Ghost     Grass   70.0   131.0    100.0     86.0
# 860  782     Jangmo-o    Dragon       NaN   45.0    55.0     65.0     45.0
# 861  783     Hakamo-o    Dragon  Fighting   55.0    75.0     90.0     65.0
# 862  784      Kommo-o    Dragon  Fighting   75.0   110.0    125.0    100.0
# 863  785    Tapu-koko  Electric     Fairy   70.0   115.0     85.0     95.0
# 864  786    Tapu-lele   Psychic     Fairy   70.0    85.0     75.0    130.0
# 865  787    Tapu-bulu     Grass     Fairy   70.0   130.0    115.0     85.0
# 866  788    Tapu-fini     Water     Fairy   70.0    75.0    115.0     95.0
# 867  789       Cosmog   Psychic       NaN   43.0    29.0     31.0     29.0
# 868  790      Cosmoem   Psychic       NaN   43.0    29.0    131.0     29.0
# 869  791     Solgaleo   Psychic     Steel  137.0   137.0    107.0    113.0
# 870  792       Lunala   Psychic     Ghost  137.0   113.0     89.0    137.0
# 871  793     Nihilego      Rock    Poison  109.0    53.0     47.0    127.0
# 872  794     Buzzwole       Bug  Fighting  107.0   139.0    139.0     53.0
# 873  795    Pheromosa       Bug  Fighting   71.0   137.0     37.0    137.0
# 874  796    Xurkitree  Electric       NaN   83.0    89.0     71.0    173.0
# 875  797   Celesteela     Steel    Flying   97.0   101.0    103.0    107.0
# 876  798      Kartana     Grass     Steel   59.0   181.0    131.0     59.0
# 877  799     Guzzlord      Dark    Dragon  223.0   101.0     53.0     97.0
# 878  800     Necrozma   Psychic       NaN   97.0   107.0    101.0    127.0
# 879  801     Magearna     Steel     Fairy   80.0    95.0    115.0    130.0
# 880  802    Marshadow  Fighting     Ghost   90.0   125.0     80.0     90.0
# 881  803      Poipole    Poison       NaN   67.0    73.0     67.0     73.0
# 882  804    Naganadel    Poison    Dragon   73.0    73.0     73.0    127.0
# 883  805    Stakataka      Rock     Steel   61.0   131.0    211.0     53.0
# 884  806  Blacephalon      Fire     Ghost   53.0   127.0     53.0    151.0
# 885  807      Zeraora  Electric       NaN   88.0   112.0     75.0    102.0
#
#      Sp. Def  Speed  Generation  Legendary  Height  Weight  Base Experience  \
# 0       65.0   45.0         1.0      False     0.7     6.9               64
# 1       80.0   60.0         1.0      False     1.0    13.0              142
# 2      100.0   80.0         1.0      False     2.0   100.0              236
# 4       50.0   65.0         1.0      False     0.6     8.5               62
# 5       65.0   80.0         1.0      False     1.1    19.0              142
# 6       85.0  100.0         1.0      False     1.7    90.5              240
# 9       64.0   43.0         1.0      False     0.5     9.0               63
# 10      80.0   58.0         1.0      False     1.0    22.5              142
# 11     105.0   78.0         1.0      False     1.6    85.5              239
# 13      20.0   45.0         1.0      False     0.3     2.9               39
# 14      25.0   30.0         1.0      False     0.7     9.9               72
# 15      80.0   70.0         1.0      False     1.1    32.0              178
# 16      20.0   50.0         1.0      False     0.3     3.2               39
# 17      25.0   35.0         1.0      False     0.6    10.0               72
# 18      80.0   75.0         1.0      False     1.0    29.5              178
# 20      35.0   56.0         1.0      False     0.3     1.8               50
# 21      50.0   71.0         1.0      False     1.1    30.0              122
# 22      70.0  101.0         1.0      False     1.5    39.5              216
# 24      35.0   72.0         1.0      False     0.3     3.5               51
# 25      70.0   97.0         1.0      False     0.7    18.5              145
# 26      31.0   70.0         1.0      False     0.3     2.0               52
# 27      61.0  100.0         1.0      False     1.2    38.0              155
# 28      54.0   55.0         1.0      False     2.0     6.9               58
# 29      79.0   80.0         1.0      False     3.5    65.0              157
# 30      50.0   90.0         1.0      False     0.4     6.0              112
# 31      80.0  110.0         1.0      False     0.8    30.0              218
# 32      30.0   40.0         1.0      False     0.6    12.0               60
# 33      55.0   65.0         1.0      False     1.0    29.5              158
# 34      40.0   41.0         1.0      False     0.4     7.0               55
# 35      55.0   56.0         1.0      False     0.8    20.0              128
# ..       ...    ...         ...        ...     ...     ...              ...
# 856    105.0   96.0         7.0      False     0.2     0.7              167
# 857     70.0   92.0         7.0      False     0.9    19.0              166
# 858     91.0   36.0         7.0      False     3.0   185.0              170
# 859     90.0   40.0         7.0      False     3.9   210.0              181
# 860     45.0   45.0         7.0      False     0.6    29.7               60
# 861     70.0   65.0         7.0      False     1.2    47.0              147
# 862    105.0   85.0         7.0      False     1.6    78.2              270
# 863     75.0  130.0         7.0       True     1.8    20.5              257
# 864    115.0   95.0         7.0       True     1.2    18.6              257
# 865     95.0   75.0         7.0       True     1.9    45.5              257
# 866    130.0   85.0         7.0       True     1.3    21.2              257
# 867     31.0   37.0         7.0       True     0.2     0.1               40
# 868    131.0   37.0         7.0       True     0.1   999.9              140
# 869     89.0   97.0         7.0       True     3.4   230.0              306
# 870    107.0   97.0         7.0       True     4.0   120.0              306
# 871    131.0  103.0         7.0      False     1.2    55.5              257
# 872     53.0   79.0         7.0      False     2.4   333.6              257
# 873     37.0  151.0         7.0      False     1.8    25.0              257
# 874     71.0   83.0         7.0      False     3.8   100.0              257
# 875    101.0   61.0         7.0      False     9.2   999.9              257
# 876     31.0  109.0         7.0      False     0.3     0.1              257
# 877     53.0   43.0         7.0      False     5.5   888.0              257
# 878     89.0   79.0         7.0       True     2.4   230.0              270
# 879    115.0   65.0         7.0      False     1.0    80.5              270
# 880     90.0  125.0         7.0      False     0.7    22.2              270
# 881     67.0   73.0         7.0      False     0.6     1.8              189
# 882     73.0  121.0         7.0      False     3.6   150.0              243
# 883    101.0   13.0         7.0      False     5.5   820.0              257
# 884     79.0  107.0         7.0      False     1.8    13.0              257
# 885     80.0  143.0         7.0      False     1.5    44.5              270
#
#       Mega
# 0    False
# 1    False
# 2    False
# 4    False
# 5    False
# 6    False
# 9    False
# 10   False
# 11   False
# 13   False
# 14   False
# 15   False
# 16   False
# 17   False
# 18   False
# 20   False
# 21   False
# 22   False
# 24   False
# 25   False
# 26   False
# 27   False
# 28   False
# 29   False
# 30   False
# 31   False
# 32   False
# 33   False
# 34   False
# 35   False
# ..     ...
# 856  False
# 857  False
# 858  False
# 859  False
# 860  False
# 861  False
# 862  False
# 863  False
# 864  False
# 865  False
# 866  False
# 867  False
# 868  False
# 869  False
# 870  False
# 871  False
# 872  False
# 873  False
# 874  False
# 875  False
# 876  False
# 877  False
# 878  False
# 879  False
# 880  False
# 881  False
# 882  False
# 883  False
# 884  False
# 885  False
#
# [807 rows x 16 columns]

# %%
df_noforme = df[~df["Name"].str.contains(' forme')]

# %% [markdown]
# ### Visualizations
#
# Now we'll see some visualizations about those pokemon status/information like battle stats (atk, defense, speed...)
# and compare all the differences. Each pokemon type (water, fire, grass...) has its own color and those colors will be used to represent them for a better understanding.

# %%
sns.countplot(x="Type 1", data=df_unique, palette=type1_colors).set_title('Pokemon first type sum');

# %%
sns.countplot(x="Type 2", data=df_unique, palette=type1_colors).set_title('Pokemon second type sum');

# %%
sns.countplot(x="Type 1", data=df_unique.loc[df_unique['Type 2'].isna()], palette=type1_colors).set_title('Pure type Pokemons sum');

# %%
sns.countplot(x="Type 1", data=df_unique.loc[df_unique['Type 2'].notnull()], palette=type1_colors).set_title('(not) Pure type Pokemons sum');

# %% [markdown]
# ### Create color palette from pokemon type

# %%
def get_color_by_type(dataframe):
    palette_by_name = {}
    for index, row in dataframe.iterrows():
        palette_by_name[row['Name']] = type1_colors[row['Type 1']]
    return palette_by_name

# %%
sns.barplot(x="Attack", y='Name', data=df.nlargest(10, 'Attack'), palette=get_color_by_type(df.nlargest(10, 'Attack'))).set_title('Top 10 Highest Attack');

# %%
sns.barplot(x="Attack", y='Name', palette=get_color_by_type(df.loc[df.Legendary == False].nlargest(10, 'Attack')), data=df.loc[df.Legendary == False].nlargest(10, 'Attack')).set_title('Top 10 Highest Attack (No Legendary)');

# %%
sns.barplot(x="Attack", y='Name', palette=get_color_by_type(df.loc[df.Mega == False].nlargest(10, 'Attack')),data=df.loc[df.Mega == False].nlargest(10, 'Attack')).set_title('Top 10 Highest Attack (No Mega)');

# %%
sns.barplot(x="Attack", y='Name',palette=get_color_by_type(df.loc[((df.Legendary == False) & (df.Mega == False) )].nlargest(10, 'Attack')), data=df.loc[((df.Legendary == False) & (df.Mega == False))].nlargest(10, 'Attack')).set_title('Top 10 Highest Attack (No Legendary and No Mega)');

# %%
sns.barplot(x="HP", y='Name', palette=get_color_by_type(df.nlargest(10, 'HP')), data=df.nlargest(10, 'HP')).set_title('Top 10 Highest HP');

# %%
sns.barplot(x="Defense", y='Name', palette=get_color_by_type(df.nlargest(10, 'Defense')),data=df.nlargest(10, 'Defense')).set_title('Top 10 Highest Defense');

# %%
sns.barplot(x="Speed", y='Name', palette=get_color_by_type(df.nlargest(10, 'Speed')), data=df.nlargest(10, 'Speed')).set_title('Top 10 Highest Speed');

# %%
df_unique.Legendary.value_counts(normalize=False).plot(kind='bar', title='Non Legendary VS Legendary');

# %%
df.loc[df.Legendary == True]
# Out:
#        #                      Name    Type 1    Type 2     HP  Attack  \
# 156  144                  Articuno       Ice    Flying   90.0    85.0
# 157  145                    Zapdos  Electric    Flying   90.0    90.0
# 158  146                   Moltres      Fire    Flying   90.0   100.0
# 162  150                    Mewtwo   Psychic       NaN  106.0   110.0
# 163  150       Mewtwomega mewtwo x   Psychic  Fighting  106.0   190.0
# 164  150       Mewtwomega mewtwo y   Psychic       NaN  106.0   150.0
# 262  243                    Raikou  Electric       NaN   90.0    85.0
# 263  244                     Entei      Fire       NaN  115.0   115.0
# 264  245                   Suicune     Water       NaN  100.0    75.0
# 269  249                     Lugia   Psychic    Flying  106.0    90.0
# 270  250                     Ho-oh      Fire    Flying  106.0   130.0
# 414  377                  Regirock      Rock       NaN   80.0   100.0
# 415  378                    Regice       Ice       NaN   80.0    50.0
# 416  379                 Registeel     Steel       NaN   80.0    75.0
# 417  380                    Latias    Dragon   Psychic   80.0    80.0
# 418  380         Latiasmega latias    Dragon   Psychic   80.0   100.0
# 419  381                    Latios    Dragon   Psychic   80.0    90.0
# 420  381         Latiosmega latios    Dragon   Psychic   80.0   130.0
# 421  382                    Kyogre     Water       NaN  100.0   100.0
# 422  382       Kyogreprimal kyogre     Water       NaN  100.0   150.0
# 423  383                   Groudon    Ground       NaN  100.0   150.0
# 424  383     Groudonprimal groudon    Ground      Fire  100.0   180.0
# 425  384                  Rayquaza    Dragon    Flying  105.0   150.0
# 426  384     Rayquazamega rayquaza    Dragon    Flying  105.0   180.0
# 427  385                   Jirachi     Steel   Psychic  100.0   100.0
# 428  386        Deoxysnormal forme   Psychic       NaN   50.0   150.0
# 429  386        Deoxysattack forme   Psychic       NaN   50.0   180.0
# 430  386       Deoxysdefense forme   Psychic       NaN   50.0    70.0
# 431  386         Deoxysspeed forme   Psychic       NaN   50.0    95.0
# 537  480                      Uxie   Psychic       NaN   75.0    75.0
# ..   ...                       ...       ...       ...    ...     ...
# 702  641   Tornadusincarnate forme    Flying       NaN   79.0   115.0
# 703  641     Tornadustherian forme    Flying       NaN   79.0   100.0
# 704  642  Thundurusincarnate forme  Electric    Flying   79.0   115.0
# 705  642    Thundurustherian forme  Electric    Flying   79.0   105.0
# 706  643                  Reshiram    Dragon      Fire  100.0   120.0
# 707  644                    Zekrom    Dragon  Electric  100.0   150.0
# 708  645   Landorusincarnate forme    Ground    Flying   89.0   125.0
# 709  645     Landorustherian forme    Ground    Flying   89.0   145.0
# 710  646                    Kyurem    Dragon       Ice  125.0   130.0
# 711  646        Kyuremblack kyurem    Dragon       Ice  125.0   170.0
# 712  646        Kyuremwhite kyurem    Dragon       Ice  125.0   120.0
# 792  716                   Xerneas     Fairy       NaN  126.0   131.0
# 793  717                   Yveltal      Dark    Flying  126.0   131.0
# 794  718          Zygarde50% forme    Dragon    Ground  108.0   100.0
# 795  719                   Diancie      Rock     Fairy   50.0   100.0
# 796  719       Dianciemega diancie      Rock     Fairy   50.0   160.0
# 797  720       Hoopahoopa confined   Psychic     Ghost   80.0   110.0
# 798  720        Hoopahoopa unbound   Psychic      Dark   80.0   160.0
# 799  721                 Volcanion      Fire     Water   80.0   110.0
# 850  772                 Type-null    Normal       NaN   95.0    95.0
# 851  773                  Silvally    Normal       NaN   95.0    95.0
# 863  785                 Tapu-koko  Electric     Fairy   70.0   115.0
# 864  786                 Tapu-lele   Psychic     Fairy   70.0    85.0
# 865  787                 Tapu-bulu     Grass     Fairy   70.0   130.0
# 866  788                 Tapu-fini     Water     Fairy   70.0    75.0
# 867  789                    Cosmog   Psychic       NaN   43.0    29.0
# 868  790                   Cosmoem   Psychic       NaN   43.0    29.0
# 869  791                  Solgaleo   Psychic     Steel  137.0   137.0
# 870  792                    Lunala   Psychic     Ghost  137.0   113.0
# 878  800                  Necrozma   Psychic       NaN   97.0   107.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Height  Weight  \
# 156    100.0     95.0    125.0   85.0         1.0       True     1.7    55.4
# 157     85.0    125.0     90.0  100.0         1.0       True     1.6    52.6
# 158     90.0    125.0     85.0   90.0         1.0       True     2.0    60.0
# 162     90.0    154.0     90.0  130.0         1.0       True     2.0   122.0
# 163    100.0    154.0    100.0  130.0         1.0       True     2.0   122.0
# 164     70.0    194.0    120.0  140.0         1.0       True     2.0   122.0
# 262     75.0    115.0    100.0  115.0         2.0       True     1.9   178.0
# 263     85.0     90.0     75.0  100.0         2.0       True     2.1   198.0
# 264    115.0     90.0    115.0   85.0         2.0       True     2.0   187.0
# 269    130.0     90.0    154.0  110.0         2.0       True     5.2   216.0
# 270     90.0    110.0    154.0   90.0         2.0       True     3.8   199.0
# 414    200.0     50.0    100.0   50.0         3.0       True     1.7   230.0
# 415    100.0    100.0    200.0   50.0         3.0       True     1.8   175.0
# 416    150.0     75.0    150.0   50.0         3.0       True     1.9   205.0
# 417     90.0    110.0    130.0  110.0         3.0       True     1.4    40.0
# 418    120.0    140.0    150.0  110.0         3.0       True     1.4    40.0
# 419     80.0    130.0    110.0  110.0         3.0       True     2.0    60.0
# 420    100.0    160.0    120.0  110.0         3.0       True     2.0    60.0
# 421     90.0    150.0    140.0   90.0         3.0       True     4.5   352.0
# 422     90.0    180.0    160.0   90.0         3.0       True     4.5   352.0
# 423    140.0    100.0     90.0   90.0         3.0       True     3.5   950.0
# 424    160.0    150.0     90.0   90.0         3.0       True     3.5   950.0
# 425     90.0    150.0     90.0   95.0         3.0       True     7.0   206.5
# 426    100.0    180.0    100.0  115.0         3.0       True     7.0   206.5
# 427    100.0    100.0    100.0  100.0         3.0       True     0.3     1.1
# 428     50.0    150.0     50.0  150.0         3.0       True     1.7    60.8
# 429     20.0    180.0     20.0  150.0         3.0       True     1.7    60.8
# 430    160.0     70.0    160.0   90.0         3.0       True     1.7    60.8
# 431     90.0     95.0     90.0  180.0         3.0       True     1.7    60.8
# 537    130.0     75.0    130.0   95.0         4.0       True     0.3     0.3
# ..       ...      ...      ...    ...         ...        ...     ...     ...
# 702     70.0    125.0     80.0  111.0         5.0       True     1.5    63.0
# 703     80.0    110.0     90.0  121.0         5.0       True     1.5    63.0
# 704     70.0    125.0     80.0  111.0         5.0       True     1.5    61.0
# 705     70.0    145.0     80.0  101.0         5.0       True     1.5    61.0
# 706    100.0    150.0    120.0   90.0         5.0       True     3.2   330.0
# 707    120.0    120.0    100.0   90.0         5.0       True     2.9   345.0
# 708     90.0    115.0     80.0  101.0         5.0       True     1.5    68.0
# 709     90.0    105.0     80.0   91.0         5.0       True     1.5    68.0
# 710     90.0    130.0     90.0   95.0         5.0       True     3.0   325.0
# 711    100.0    120.0     90.0   95.0         5.0       True     3.0   325.0
# 712     90.0    170.0    100.0   95.0         5.0       True     3.0   325.0
# 792     95.0    131.0     98.0   99.0         6.0       True     3.0   215.0
# 793     95.0    131.0     98.0   99.0         6.0       True     5.8   203.0
# 794    121.0     81.0     95.0   95.0         6.0       True     5.0   305.0
# 795    150.0    100.0    150.0   50.0         6.0       True     0.7     8.8
# 796    110.0    160.0    110.0  110.0         6.0       True     0.7     8.8
# 797     60.0    150.0    130.0   70.0         6.0       True     0.5     9.0
# 798     60.0    170.0    130.0   80.0         6.0       True     0.5     9.0
# 799    120.0    130.0     90.0   70.0         6.0       True     1.7   195.0
# 850     95.0     95.0     95.0   59.0         7.0       True     1.9   120.5
# 851     95.0     95.0     95.0   95.0         7.0       True     2.3   100.5
# 863     85.0     95.0     75.0  130.0         7.0       True     1.8    20.5
# 864     75.0    130.0    115.0   95.0         7.0       True     1.2    18.6
# 865    115.0     85.0     95.0   75.0         7.0       True     1.9    45.5
# 866    115.0     95.0    130.0   85.0         7.0       True     1.3    21.2
# 867     31.0     29.0     31.0   37.0         7.0       True     0.2     0.1
# 868    131.0     29.0    131.0   37.0         7.0       True     0.1   999.9
# 869    107.0    113.0     89.0   97.0         7.0       True     3.4   230.0
# 870     89.0    137.0    107.0   97.0         7.0       True     4.0   120.0
# 878    101.0    127.0     89.0   79.0         7.0       True     2.4   230.0
#
#      Base Experience   Mega  Evolve at  Evolve
# 156              261  False          0   False
# 157              261  False          0   False
# 158              261  False          0   False
# 162              306  False          0   False
# 163              306   True          0   False
# 164              306   True          0   False
# 262              261  False          0   False
# 263              261  False          0   False
# 264              261  False          0   False
# 269              306  False          0   False
# 270              306  False          0   False
# 414              261  False          0   False
# 415              261  False          0   False
# 416              261  False          0   False
# 417              270  False          0   False
# 418              270   True          0   False
# 419              270  False          0   False
# 420              270   True          0   False
# 421              302  False          0   False
# 422              302  False          0   False
# 423              302  False          0   False
# 424              302  False          0   False
# 425              306  False          0   False
# 426              306   True          0   False
# 427              270  False          0   False
# 428              270  False          0   False
# 429              270  False          0   False
# 430              270  False          0   False
# 431              270  False          0   False
# 537              261  False          0   False
# ..               ...    ...        ...     ...
# 702              261  False          0   False
# 703              261  False          0   False
# 704              261  False          0   False
# 705              261  False          0   False
# 706              306  False          0   False
# 707              306  False          0   False
# 708              270  False          0   False
# 709              270  False          0   False
# 710              297  False          0   False
# 711              297  False          0   False
# 712              297  False          0   False
# 792              306  False          0   False
# 793              306  False          0   False
# 794              270  False          0   False
# 795              270  False          0   False
# 796              270   True          0   False
# 797              270  False          0   False
# 798              270  False          0   False
# 799              270  False          0   False
# 850              107  False          0   False
# 851              257  False          0   False
# 863              257  False          0   False
# 864              257  False          0   False
# 865              257  False          0   False
# 866              257  False          0   False
# 867               40  False         43    True
# 868              140  False         53    True
# 869              306  False          0   False
# 870              306  False          0   False
# 878              270  False          0   False
#
# [76 rows x 18 columns]

# %%
sns.countplot(x="Generation", data=df_unique.loc[df_unique.Legendary == True]).set_title('Legendary sum by Generation');

# %% [markdown]
# ### Histogram

# %%
# df_num = df_unique.select_dtypes(include = ['float64', 'int64']);
df_num = df_unique[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Height','Weight','Base Experience']]
df_num.hist(figsize=(16, 20), bins=25, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# ## Merge data with level and add 'evolve' column

# %%
df_level = pd.read_csv('pokemon evolutions by level.csv')
# df.set_index(['#'], inplace=True)

# %%
df_level.head()
# Out:
#    Level  Ndex  MS     Pokémon Type Unnamed: 5
# 0      7    10 NaN    Caterpie  Bug        NaN
# 1      7    13 NaN      Weedle  Bug     Poison
# 2      7   265 NaN     Wurmple  Bug        NaN
# 3      9   664 NaN  Scatterbug  Bug        NaN
# 4     10    11 NaN     Metapod  Bug        NaN

# %%
df_level.tail()
# Out:
#      Level  Ndex  MS    Pokémon    Type Unnamed: 5
# 276     54   629 NaN    Vullaby    Dark     Flying
# 277     55   148 NaN  Dragonair  Dragon        NaN
# 278     55   247 NaN    Pupitar    Rock     Ground
# 279     59   636 NaN   Larvesta     Bug       Fire
# 280     64   634 NaN   Zweilous    Dark     Dragon

# %%
df['Evolve at'] = 0
df['Evolve'] = False
df.head()
# Out:
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0
# 1  2                Ivysaur  Grass  Poison  60.0    62.0     63.0     80.0
# 2  3               Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 3  3  Venusaurmega venusaur  Grass  Poison  80.0   100.0    123.0    122.0
# 4  4             Charmander   Fire     NaN  39.0    52.0     43.0     60.0
#
#    Sp. Def  Speed  Generation  Legendary  Height  Weight  Base Experience  \
# 0     65.0   45.0         1.0      False     0.7     6.9               64
# 1     80.0   60.0         1.0      False     1.0    13.0              142
# 2    100.0   80.0         1.0      False     2.0   100.0              236
# 3    120.0   80.0         1.0      False     2.0   100.0              236
# 4     50.0   65.0         1.0      False     0.6     8.5               62
#
#     Mega  Evolve at  Evolve
# 0  False          0   False
# 1  False          0   False
# 2  False          0   False
# 3   True          0   False
# 4  False          0   False

# %%
for index, row in df_level.iterrows():
    df.loc[df['#'] == row['Ndex'], 'Evolve at'] = row['Level']
    df.loc[df['#'] == row['Ndex'], 'Evolve'] = True

df.head()
# Out:
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0
# 1  2                Ivysaur  Grass  Poison  60.0    62.0     63.0     80.0
# 2  3               Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 3  3  Venusaurmega venusaur  Grass  Poison  80.0   100.0    123.0    122.0
# 4  4             Charmander   Fire     NaN  39.0    52.0     43.0     60.0
#
#    Sp. Def  Speed  Generation  Legendary  Height  Weight  Base Experience  \
# 0     65.0   45.0         1.0      False     0.7     6.9               64
# 1     80.0   60.0         1.0      False     1.0    13.0              142
# 2    100.0   80.0         1.0      False     2.0   100.0              236
# 3    120.0   80.0         1.0      False     2.0   100.0              236
# 4     50.0   65.0         1.0      False     0.6     8.5               62
#
#     Mega  Evolve at  Evolve
# 0  False         16    True
# 1  False         32    True
# 2  False          0   False
# 3   True          0   False
# 4  False         16    True

# %%
df.tail()
# Out:
#        #         Name    Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 881  803      Poipole    Poison     NaN  67.0    73.0     67.0     73.0
# 882  804    Naganadel    Poison  Dragon  73.0    73.0     73.0    127.0
# 883  805    Stakataka      Rock   Steel  61.0   131.0    211.0     53.0
# 884  806  Blacephalon      Fire   Ghost  53.0   127.0     53.0    151.0
# 885  807      Zeraora  Electric     NaN  88.0   112.0     75.0    102.0
#
#      Sp. Def  Speed  Generation  Legendary  Height  Weight  Base Experience  \
# 881     67.0   73.0         7.0      False     0.6     1.8              189
# 882     73.0  121.0         7.0      False     3.6   150.0              243
# 883    101.0   13.0         7.0      False     5.5   820.0              257
# 884     79.0  107.0         7.0      False     1.8    13.0              257
# 885     80.0  143.0         7.0      False     1.5    44.5              270
#
#       Mega  Evolve at  Evolve
# 881  False          0   False
# 882  False          0   False
# 883  False          0   False
# 884  False          0   False
# 885  False          0   False

# %%
df_unique = df.drop_duplicates(subset="#")

# %% [markdown]
# ### Starters

# %%
df_starters1 = df.loc[df['#'].isin([1, 4,7,
                           152, 155,158,
                           252,255,258,
                           387,390,393,
                           495,498,501,
                           650,653,656,
                            722, 725, 728
                          ])]
df_starters1.filter(['Name', 'Type 1','Type 2','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Generation','Height','Weight','Base Experience','Evolve at'])
# Out:
#            Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0     Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0     65.0
# 4    Charmander   Fire     NaN  39.0    52.0     43.0     60.0     50.0
# 9      Squirtle  Water     NaN  44.0    48.0     65.0     50.0     64.0
# 166   Chikorita  Grass     NaN  45.0    49.0     65.0     49.0     65.0
# 169   Cyndaquil   Fire     NaN  39.0    52.0     43.0     60.0     50.0
# 172    Totodile  Water     NaN  50.0    65.0     64.0     44.0     48.0
# 272     Treecko  Grass     NaN  40.0    45.0     35.0     65.0     55.0
# 276     Torchic   Fire     NaN  45.0    60.0     40.0     70.0     50.0
# 280      Mudkip  Water     NaN  50.0    70.0     50.0     50.0     50.0
# 432     Turtwig  Grass     NaN  55.0    68.0     64.0     45.0     55.0
# 435    Chimchar   Fire     NaN  44.0    58.0     44.0     58.0     44.0
# 438      Piplup  Water     NaN  53.0    51.0     53.0     61.0     56.0
# 554       Snivy  Grass     NaN  45.0    45.0     55.0     45.0     55.0
# 557       Tepig   Fire     NaN  65.0    63.0     45.0     45.0     45.0
# 560    Oshawott  Water     NaN  55.0    55.0     45.0     63.0     45.0
# 718     Chespin  Grass     NaN  56.0    61.0     65.0     48.0     45.0
# 721    Fennekin   Fire     NaN  40.0    45.0     40.0     62.0     60.0
# 724     Froakie  Water     NaN  41.0    56.0     40.0     62.0     44.0
# 800      Rowlet  Grass  Flying  68.0    55.0     55.0     50.0     50.0
# 803      Litten   Fire     NaN  45.0    65.0     40.0     60.0     40.0
# 806     Popplio  Water     NaN  50.0    54.0     54.0     66.0     56.0
#
#      Speed  Generation  Height  Weight  Base Experience  Evolve at
# 0     45.0         1.0     0.7     6.9               64         16
# 4     65.0         1.0     0.6     8.5               62         16
# 9     43.0         1.0     0.5     9.0               63         16
# 166   45.0         2.0     0.9     6.4               64         16
# 169   65.0         2.0     0.5     7.9               62         14
# 172   43.0         2.0     0.6     9.5               63         18
# 272   70.0         3.0     0.5     5.0               62         16
# 276   45.0         3.0     0.4     2.5               62         16
# 280   40.0         3.0     0.4     7.6               62         16
# 432   31.0         4.0     0.4    10.2               64         18
# 435   61.0         4.0     0.5     6.2               62         14
# 438   40.0         4.0     0.4     5.2               63         16
# 554   63.0         5.0     0.6     8.1               62         17
# 557   45.0         5.0     0.5     9.9               62         17
# 560   45.0         5.0     0.5     5.9               62         17
# 718   38.0         6.0     0.4     9.0               63         16
# 721   60.0         6.0     0.4     9.4               61         16
# 724   71.0         6.0     0.3     7.0               63         16
# 800   42.0         7.0     0.3     1.5               64         17
# 803   70.0         7.0     0.4     4.3               64         17
# 806   40.0         7.0     0.4     7.5               64         17

# %%
df_starters1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 806
# Data columns (total 18 columns):
# #                  21 non-null int64
# Name               21 non-null object
# Type 1             21 non-null object
# Type 2             2 non-null object
# HP                 21 non-null float64
# Attack             21 non-null float64
# Defense            21 non-null float64
# Sp. Atk            21 non-null float64
# Sp. Def            21 non-null float64
# Speed              21 non-null float64
# Generation         21 non-null float64
# Legendary          21 non-null bool
# Height             21 non-null float64
# Weight             21 non-null float64
# Base Experience    21 non-null int64
# Mega               21 non-null bool
# Evolve at          21 non-null int64
# Evolve             21 non-null bool
# dtypes: bool(3), float64(9), int64(3), object(3)
# memory usage: 2.7+ KB

# %%
df_starters2 = df.loc[df['#'].isin([2,5,8,
                           153, 156,159,
                           253,256,259,
                           388,391,394,
                           496,499,502,
                           651,654,657,
                            723, 726, 729
                          ])]
df_starters2.filter(['Name', 'Type 1','Type 2','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Generation','Height','Weight','Base Experience','Evolve at'])
# Out:
#            Name Type 1    Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1       Ivysaur  Grass    Poison  60.0    62.0     63.0     80.0     80.0
# 5    Charmeleon   Fire       NaN  58.0    64.0     58.0     80.0     65.0
# 10    Wartortle  Water       NaN  59.0    63.0     80.0     65.0     80.0
# 167     Bayleef  Grass       NaN  60.0    62.0     80.0     63.0     80.0
# 170     Quilava   Fire       NaN  58.0    64.0     58.0     80.0     65.0
# 173    Croconaw  Water       NaN  65.0    80.0     80.0     59.0     63.0
# 273     Grovyle  Grass       NaN  50.0    65.0     45.0     85.0     65.0
# 277   Combusken   Fire  Fighting  60.0    85.0     60.0     85.0     60.0
# 281   Marshtomp  Water    Ground  70.0    85.0     70.0     60.0     70.0
# 433      Grotle  Grass       NaN  75.0    89.0     85.0     55.0     65.0
# 436    Monferno   Fire  Fighting  64.0    78.0     52.0     78.0     52.0
# 439    Prinplup  Water       NaN  64.0    66.0     68.0     81.0     76.0
# 555     Servine  Grass       NaN  60.0    60.0     75.0     60.0     75.0
# 558     Pignite   Fire  Fighting  90.0    93.0     55.0     70.0     55.0
# 561      Dewott  Water       NaN  75.0    75.0     60.0     83.0     60.0
# 719   Quilladin  Grass       NaN  61.0    78.0     95.0     56.0     58.0
# 722     Braixen   Fire       NaN  59.0    59.0     58.0     90.0     70.0
# 725   Frogadier  Water       NaN  54.0    63.0     52.0     83.0     56.0
# 801     Dartrix  Grass    Flying  78.0    75.0     75.0     70.0     70.0
# 804    Torracat   Fire       NaN  65.0    85.0     50.0     80.0     50.0
# 807     Brionne  Water       NaN  60.0    69.0     69.0     91.0     81.0
#
#      Speed  Generation  Height  Weight  Base Experience  Evolve at
# 1     60.0         1.0     1.0    13.0              142         32
# 5     80.0         1.0     1.1    19.0              142         36
# 10    58.0         1.0     1.0    22.5              142         36
# 167   60.0         2.0     1.2    15.8              142         32
# 170   80.0         2.0     0.9    19.0              142         36
# 173   58.0         2.0     1.1    25.0              142         30
# 273   95.0         3.0     0.9    21.6              142         36
# 277   55.0         3.0     0.9    19.5              142         36
# 281   50.0         3.0     0.7    28.0              142         36
# 433   36.0         4.0     1.1    97.0              142         32
# 436   81.0         4.0     0.9    22.0              142         36
# 439   50.0         4.0     0.8    23.0              142         36
# 555   83.0         5.0     0.8    16.0              145         36
# 558   55.0         5.0     1.0    55.5              146         36
# 561   60.0         5.0     0.8    24.5              145         36
# 719   57.0         6.0     0.7    29.0              142         36
# 722   73.0         6.0     1.0    14.5              143         36
# 725   97.0         6.0     0.6    10.9              142         36
# 801   52.0         7.0     0.7    16.0              147         34
# 804   90.0         7.0     0.7    25.0              147         34
# 807   50.0         7.0     0.6    17.5              147         34

# %%
df_starters3 = df.loc[df['#'].isin([3,6,9,
                           154, 157,160,
                           254,257,260,
                           389,392,395,
                           497,500,503,
                           652,655,658,
                            724, 727, 730
                          ])]
df_starters3.filter(['Name', 'Type 1','Type 2','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Generation','Height','Weight','Base Experience','Evolve at'])
# Out:
#                           Name Type 1    Type 2     HP  Attack  Defense  \
# 2                     Venusaur  Grass    Poison   80.0    82.0     83.0
# 3        Venusaurmega venusaur  Grass    Poison   80.0   100.0    123.0
# 6                    Charizard   Fire    Flying   78.0    84.0     78.0
# 7    Charizardmega charizard x   Fire    Dragon   78.0   130.0    111.0
# 8    Charizardmega charizard y   Fire    Flying   78.0   104.0     78.0
# 11                   Blastoise  Water       NaN   79.0    83.0    100.0
# 12     Blastoisemega blastoise  Water       NaN   79.0   103.0    120.0
# 168                   Meganium  Grass       NaN   80.0    82.0    100.0
# 171                 Typhlosion   Fire       NaN   78.0    84.0     78.0
# 174                 Feraligatr  Water       NaN   85.0   105.0    100.0
# 274                   Sceptile  Grass       NaN   70.0    85.0     65.0
# 275      Sceptilemega sceptile  Grass    Dragon   70.0   110.0     75.0
# 278                   Blaziken   Fire  Fighting   80.0   120.0     70.0
# 279      Blazikenmega blaziken   Fire  Fighting   80.0   160.0     80.0
# 282                   Swampert  Water    Ground  100.0   110.0     90.0
# 283      Swampertmega swampert  Water    Ground  100.0   150.0    110.0
# 434                   Torterra  Grass    Ground   95.0   109.0    105.0
# 437                  Infernape   Fire  Fighting   76.0   104.0     71.0
# 440                   Empoleon  Water     Steel   84.0    86.0     88.0
# 556                  Serperior  Grass       NaN   75.0    75.0     95.0
# 559                     Emboar   Fire  Fighting  110.0   123.0     65.0
# 562                   Samurott  Water       NaN   95.0   100.0     85.0
# 720                 Chesnaught  Grass  Fighting   88.0   107.0    122.0
# 723                    Delphox   Fire   Psychic   75.0    69.0     72.0
# 726                   Greninja  Water      Dark   72.0    95.0     67.0
# 802                  Decidueye  Grass     Ghost   78.0   107.0     75.0
# 805                 Incineroar   Fire      Dark   95.0   115.0     90.0
# 808                  Primarina  Water     Fairy   80.0    74.0     74.0
#
#      Sp. Atk  Sp. Def  Speed  Generation  Height  Weight  Base Experience  \
# 2      100.0    100.0   80.0         1.0     2.0   100.0              236
# 3      122.0    120.0   80.0         1.0     2.0   100.0              236
# 6      109.0     85.0  100.0         1.0     1.7    90.5              240
# 7      130.0     85.0  100.0         1.0     1.7    90.5              240
# 8      159.0    115.0  100.0         1.0     1.7    90.5              240
# 11      85.0    105.0   78.0         1.0     1.6    85.5              239
# 12     135.0    115.0   78.0         1.0     1.6    85.5              239
# 168     83.0    100.0   80.0         2.0     1.8   100.5              236
# 171    109.0     85.0  100.0         2.0     1.7    79.5              240
# 174     79.0     83.0   78.0         2.0     2.3    88.8              239
# 274    105.0     85.0  120.0         3.0     1.7    52.2              239
# 275    145.0     85.0  145.0         3.0     1.7    52.2              239
# 278    110.0     70.0   80.0         3.0     1.9    52.0              239
# 279    130.0     80.0  100.0         3.0     1.9    52.0              239
# 282     85.0     90.0   60.0         3.0     1.5    81.9              241
# 283     95.0    110.0   70.0         3.0     1.5    81.9              241
# 434     75.0     85.0   56.0         4.0     2.2   310.0              236
# 437    104.0     71.0  108.0         4.0     1.2    55.0              240
# 440    111.0    101.0   60.0         4.0     1.7    84.5              239
# 556     75.0     95.0  113.0         5.0     3.3    63.0              238
# 559    100.0     65.0   65.0         5.0     1.6   150.0              238
# 562    108.0     70.0   70.0         5.0     1.5    94.6              238
# 720     74.0     75.0   64.0         6.0     1.6    90.0              239
# 723    114.0    100.0  104.0         6.0     1.5    39.0              240
# 726    103.0     71.0  122.0         6.0     1.5    40.0              239
# 802    100.0    100.0   70.0         7.0     1.6    36.6              239
# 805     80.0     90.0   60.0         7.0     1.8    83.0              239
# 808    126.0    116.0   60.0         7.0     1.8    44.0              239
#
#      Evolve at
# 2            0
# 3            0
# 6            0
# 7            0
# 8            0
# 11           0
# 12           0
# 168          0
# 171          0
# 174          0
# 274          0
# 275          0
# 278          0
# 279          0
# 282          0
# 283          0
# 434          0
# 437          0
# 440          0
# 556          0
# 559          0
# 562          0
# 720          0
# 723          0
# 726          0
# 802          0
# 805          0
# 808          0

# %% [markdown]
# ### Starters Visualizations
#
# Here we have starters status ('HP',' Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Height', 'Weight').
# <br>To see the entire image (desktop mode): https://i.imgur.com/ThSymJb.png

# %%
plot_index = 0
fig, ax = plt.subplots(8,3, figsize=[50,90])
ax = ax.flatten()
for i, x in enumerate(['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Height','Weight']):
    for j, z in enumerate([df_starters1, df_starters2, df_starters3]):
        sns.barplot(x=x, y='Name', palette=get_color_by_type(z.nlargest(10, x)), ax=ax[plot_index], data=z.nlargest(10, x)).set_title('Top 10 ' + str(x) + ' (Starters only - Evolution ' + str(j+1) + ')')
        plot_index = plot_index + 1
fig.show()
